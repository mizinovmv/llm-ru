# %%
model_id = "ai21labs/Jamba-v0.1"

# %%
import torch
import transformers
from transformers import AutoModelForCausalLM, BitsAndBytesConfig
import bitsandbytes as bnb
print("torch", torch.__version__)
print("transformers", transformers.__version__)

device_map = "sequential"
max_memory = {0:"20GiB", 1: "22GiB"}


quantization_config = BitsAndBytesConfig(load_in_4bit=True,
                                         llm_int8_skip_modules=["lm_head", "mamba"])
# quantization_config = BitsAndBytesConfig(load_in_4bit=True,
#                                          llm_int8_skip_modules=["lm_head", "mamba", "router", "self_attn", "moe.experts.0.gate_proj", "moe.experts.0.up_proj"])

model = AutoModelForCausalLM.from_pretrained(model_id,
                                             trust_remote_code=True,
                                             torch_dtype=torch.bfloat16,
                                             attn_implementation="flash_attention_2",
                                             device_map=device_map,
                                             max_memory=max_memory,
                                             quantization_config=quantization_config)
model
# Out:
# torch 2.1.2+cu121
# transformers 4.39.2
# Loading checkpoint shards:   0%|          | 0/21 [00:00<?, ?it/s]
# JambaForCausalLM(
#   (model): JambaModel(
#     (embed_tokens): Embedding(65536, 4096, padding_idx=0)
#     (layers): ModuleList(
#       (0): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (1): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (2): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (3): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (4): JambaAttentionDecoderLayer(
#         (self_attn): JambaFlashAttention2(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (5): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (6): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (7): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (8): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (9): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (10): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (11): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (12): JambaAttentionDecoderLayer(
#         (self_attn): JambaFlashAttention2(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (13): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (14): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (15): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (16): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (17): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (18): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (19): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (20): JambaAttentionDecoderLayer(
#         (self_attn): JambaFlashAttention2(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (21): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (22): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (23): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (24): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (25): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (26): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (27): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (28): JambaAttentionDecoderLayer(
#         (self_attn): JambaFlashAttention2(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (29): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (30): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (31): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#     )
#     (final_layernorm): JambaRMSNorm()
#   )
#   (lm_head): Linear(in_features=4096, out_features=65536, bias=False)
# )

# %%
import bitsandbytes.functional as F
from bitsandbytes.nn import Linear4bit
from torch.nn.modules.linear import Linear
import numpy as np
import gc

layer_snr = {}

def marchenko_pastur_threshold(sigma, n, m):
    beta = n / m if n < m else m / n
    threshold = sigma * np.sqrt((1 + np.sqrt(beta)) ** 2)
    return threshold

def estimate_sigma_with_full_iqr(S):
    q75 = torch.quantile(S, 0.75)
    q25 = torch.quantile(S, 0.25)
    iqr = q75 - q25
    sigma_estimated = (
        iqr / 1.349
    )  ## 0.6745 * sigma is the expected range between the quantiles (Q1 and Q3)
    return sigma_estimated

def calculate_snr_for_layer(module):
    if isinstance(module, Linear):
        weights = module.weight.double()
    elif isinstance(module, Linear4bit):
        weights = F.dequantize_4bit(module.weight, module.quant_state).t().double()
    else:
        assert "not Linear"
    S = torch.linalg.svdvals(weights)
    weights = weights.detach().cpu()
    S = S.detach().cpu()
    sigma_estimated = estimate_sigma_with_full_iqr(S)
    n, m = weights.shape
    mp_threshold = marchenko_pastur_threshold(sigma_estimated, n, m)
    
    signal = S[S > mp_threshold].sum()
    noise = S[S <= mp_threshold].sum()
    snr = signal / noise if noise != 0 else float("inf")
    del S, weights
    torch.cuda.empty_cache()  # Clear PyTorch's CUDA memory cache
    gc.collect()
    return snr

def assess_layers_snr(model):
    for name, module in model.named_modules():
        if isinstance(module, Linear) or isinstance(module, Linear4bit):
            print("*" * 50, flush=True)
            print(
                f"Calculating Signal to Noise Ratio at layer {name}",
                flush=True,
            )
            snr = calculate_snr_for_layer(module)
            layer_snr[name] = snr
            print(
                f"Signal to Noise Ratio at layer {name} = {snr}",
                flush=True,
            )
            print("*" * 50, flush=True)

# %%
assess_layers_snr(model)
# Out:
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.0.mamba.in_proj
# Signal to Noise Ratio at layer model.layers.0.mamba.in_proj = 9.294888408316409
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.0.mamba.x_proj
# Signal to Noise Ratio at layer model.layers.0.mamba.x_proj = 9.84220223913894
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.0.mamba.dt_proj
# Signal to Noise Ratio at layer model.layers.0.mamba.dt_proj = 7.4991185326259915
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.0.mamba.out_proj
# Signal to Noise Ratio at layer model.layers.0.mamba.out_proj = 2.5841342483567633
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.0.moe.experts.0.gate_proj
# Signal to Noise Ratio at layer model.layers.0.moe.experts.0.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.0.moe.experts.0.down_proj
# Signal to Noise Ratio at layer model.layers.0.moe.experts.0.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.0.moe.experts.0.up_proj
# Signal to Noise Ratio at layer model.layers.0.moe.experts.0.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.mamba.in_proj
# Signal to Noise Ratio at layer model.layers.1.mamba.in_proj = 5.785216782887676
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.mamba.x_proj
# Signal to Noise Ratio at layer model.layers.1.mamba.x_proj = 5.478194471022491
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.mamba.dt_proj
# Signal to Noise Ratio at layer model.layers.1.mamba.dt_proj = 3.284722551670451
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.mamba.out_proj
# Signal to Noise Ratio at layer model.layers.1.mamba.out_proj = 2.89913467713663
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.router
# Signal to Noise Ratio at layer model.layers.1.moe.router = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.0.gate_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.0.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.0.down_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.0.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.0.up_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.0.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.1.gate_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.1.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.1.down_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.1.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.1.up_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.1.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.2.gate_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.2.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.2.down_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.2.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.2.up_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.2.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.3.gate_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.3.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.3.down_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.3.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.3.up_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.3.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.4.gate_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.4.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.4.down_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.4.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.4.up_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.4.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.5.gate_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.5.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.5.down_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.5.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.5.up_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.5.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.6.gate_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.6.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.6.down_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.6.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.6.up_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.6.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.7.gate_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.7.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.7.down_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.7.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.7.up_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.7.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.8.gate_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.8.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.8.down_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.8.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.8.up_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.8.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.9.gate_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.9.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.9.down_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.9.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.9.up_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.9.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.10.gate_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.10.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.10.down_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.10.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.10.up_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.10.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.11.gate_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.11.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.11.down_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.11.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.11.up_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.11.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.12.gate_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.12.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.12.down_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.12.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.12.up_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.12.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.13.gate_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.13.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.13.down_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.13.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.13.up_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.13.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.14.gate_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.14.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.14.down_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.14.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.14.up_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.14.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.15.gate_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.15.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.15.down_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.15.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.15.up_proj
# Signal to Noise Ratio at layer model.layers.1.moe.experts.15.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.2.mamba.in_proj
# Signal to Noise Ratio at layer model.layers.2.mamba.in_proj = 15.82740683217205
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.2.mamba.x_proj
# Signal to Noise Ratio at layer model.layers.2.mamba.x_proj = 133.60279803772303
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.2.mamba.dt_proj
# Signal to Noise Ratio at layer model.layers.2.mamba.dt_proj = 126.72050867078481
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.2.mamba.out_proj
# Signal to Noise Ratio at layer model.layers.2.mamba.out_proj = 2.7847049397578014
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.2.moe.experts.0.gate_proj
# Signal to Noise Ratio at layer model.layers.2.moe.experts.0.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.2.moe.experts.0.down_proj
# Signal to Noise Ratio at layer model.layers.2.moe.experts.0.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.2.moe.experts.0.up_proj
# Signal to Noise Ratio at layer model.layers.2.moe.experts.0.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.mamba.in_proj
# Signal to Noise Ratio at layer model.layers.3.mamba.in_proj = 11.570219680263856
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.mamba.x_proj
# Signal to Noise Ratio at layer model.layers.3.mamba.x_proj = 112.12248306964787
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.mamba.dt_proj
# Signal to Noise Ratio at layer model.layers.3.mamba.dt_proj = 112.10069290891182
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.mamba.out_proj
# Signal to Noise Ratio at layer model.layers.3.mamba.out_proj = 2.5635235441462094
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.router
# Signal to Noise Ratio at layer model.layers.3.moe.router = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.0.gate_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.0.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.0.down_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.0.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.0.up_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.0.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.1.gate_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.1.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.1.down_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.1.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.1.up_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.1.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.2.gate_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.2.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.2.down_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.2.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.2.up_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.2.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.3.gate_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.3.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.3.down_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.3.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.3.up_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.3.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.4.gate_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.4.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.4.down_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.4.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.4.up_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.4.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.5.gate_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.5.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.5.down_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.5.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.5.up_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.5.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.6.gate_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.6.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.6.down_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.6.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.6.up_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.6.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.7.gate_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.7.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.7.down_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.7.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.7.up_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.7.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.8.gate_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.8.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.8.down_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.8.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.8.up_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.8.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.9.gate_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.9.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.9.down_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.9.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.9.up_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.9.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.10.gate_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.10.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.10.down_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.10.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.10.up_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.10.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.11.gate_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.11.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.11.down_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.11.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.11.up_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.11.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.12.gate_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.12.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.12.down_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.12.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.12.up_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.12.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.13.gate_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.13.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.13.down_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.13.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.13.up_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.13.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.14.gate_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.14.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.14.down_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.14.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.14.up_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.14.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.15.gate_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.15.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.15.down_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.15.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.15.up_proj
# Signal to Noise Ratio at layer model.layers.3.moe.experts.15.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.4.self_attn.q_proj
# Signal to Noise Ratio at layer model.layers.4.self_attn.q_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.4.self_attn.k_proj
# Signal to Noise Ratio at layer model.layers.4.self_attn.k_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.4.self_attn.v_proj
# Signal to Noise Ratio at layer model.layers.4.self_attn.v_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.4.self_attn.o_proj
# Signal to Noise Ratio at layer model.layers.4.self_attn.o_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.4.moe.experts.0.gate_proj
# Signal to Noise Ratio at layer model.layers.4.moe.experts.0.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.4.moe.experts.0.down_proj
# Signal to Noise Ratio at layer model.layers.4.moe.experts.0.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.4.moe.experts.0.up_proj
# Signal to Noise Ratio at layer model.layers.4.moe.experts.0.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.mamba.in_proj
# Signal to Noise Ratio at layer model.layers.5.mamba.in_proj = 11.944049262649637
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.mamba.x_proj
# Signal to Noise Ratio at layer model.layers.5.mamba.x_proj = 723.2167229626258
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.mamba.dt_proj
# Signal to Noise Ratio at layer model.layers.5.mamba.dt_proj = 1236.8903775340787
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.mamba.out_proj
# Signal to Noise Ratio at layer model.layers.5.mamba.out_proj = 2.551891063040065
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.router
# Signal to Noise Ratio at layer model.layers.5.moe.router = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.0.gate_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.0.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.0.down_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.0.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.0.up_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.0.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.1.gate_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.1.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.1.down_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.1.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.1.up_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.1.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.2.gate_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.2.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.2.down_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.2.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.2.up_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.2.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.3.gate_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.3.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.3.down_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.3.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.3.up_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.3.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.4.gate_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.4.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.4.down_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.4.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.4.up_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.4.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.5.gate_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.5.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.5.down_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.5.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.5.up_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.5.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.6.gate_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.6.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.6.down_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.6.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.6.up_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.6.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.7.gate_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.7.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.7.down_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.7.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.7.up_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.7.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.8.gate_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.8.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.8.down_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.8.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.8.up_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.8.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.9.gate_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.9.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.9.down_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.9.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.9.up_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.9.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.10.gate_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.10.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.10.down_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.10.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.10.up_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.10.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.11.gate_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.11.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.11.down_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.11.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.11.up_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.11.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.12.gate_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.12.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.12.down_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.12.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.12.up_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.12.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.13.gate_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.13.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.13.down_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.13.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.13.up_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.13.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.14.gate_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.14.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.14.down_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.14.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.14.up_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.14.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.15.gate_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.15.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.15.down_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.15.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.15.up_proj
# Signal to Noise Ratio at layer model.layers.5.moe.experts.15.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.6.mamba.in_proj
# Signal to Noise Ratio at layer model.layers.6.mamba.in_proj = 25.421425296590595
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.6.mamba.x_proj
# Signal to Noise Ratio at layer model.layers.6.mamba.x_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.6.mamba.dt_proj
# Signal to Noise Ratio at layer model.layers.6.mamba.dt_proj = 1014.0274643303285
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.6.mamba.out_proj
# Signal to Noise Ratio at layer model.layers.6.mamba.out_proj = 2.6468872076753946
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.6.moe.experts.0.gate_proj
# Signal to Noise Ratio at layer model.layers.6.moe.experts.0.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.6.moe.experts.0.down_proj
# Signal to Noise Ratio at layer model.layers.6.moe.experts.0.down_proj = inf
# **************************************************
# ...
# Signal to Noise Ratio at layer model.layers.29.moe.experts.15.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.30.mamba.in_proj
# Signal to Noise Ratio at layer model.layers.30.mamba.in_proj = 29.36518419205261
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.30.mamba.x_proj
# Signal to Noise Ratio at layer model.layers.30.mamba.x_proj = 1137.739951462403
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.30.mamba.dt_proj
# Signal to Noise Ratio at layer model.layers.30.mamba.dt_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.30.mamba.out_proj
# Signal to Noise Ratio at layer model.layers.30.mamba.out_proj = 3.1020282355404074
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.30.moe.experts.0.gate_proj
# Signal to Noise Ratio at layer model.layers.30.moe.experts.0.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.30.moe.experts.0.down_proj
# Signal to Noise Ratio at layer model.layers.30.moe.experts.0.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.30.moe.experts.0.up_proj
# Signal to Noise Ratio at layer model.layers.30.moe.experts.0.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.mamba.in_proj
# Signal to Noise Ratio at layer model.layers.31.mamba.in_proj = 11.650786927686074
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.mamba.x_proj
# Signal to Noise Ratio at layer model.layers.31.mamba.x_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.mamba.dt_proj
# Signal to Noise Ratio at layer model.layers.31.mamba.dt_proj = 777.693667690936
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.mamba.out_proj
# Signal to Noise Ratio at layer model.layers.31.mamba.out_proj = 2.6296996416941
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.router
# Signal to Noise Ratio at layer model.layers.31.moe.router = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.0.gate_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.0.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.0.down_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.0.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.0.up_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.0.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.1.gate_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.1.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.1.down_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.1.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.1.up_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.1.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.2.gate_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.2.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.2.down_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.2.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.2.up_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.2.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.3.gate_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.3.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.3.down_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.3.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.3.up_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.3.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.4.gate_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.4.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.4.down_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.4.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.4.up_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.4.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.5.gate_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.5.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.5.down_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.5.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.5.up_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.5.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.6.gate_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.6.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.6.down_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.6.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.6.up_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.6.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.7.gate_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.7.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.7.down_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.7.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.7.up_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.7.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.8.gate_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.8.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.8.down_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.8.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.8.up_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.8.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.9.gate_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.9.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.9.down_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.9.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.9.up_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.9.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.10.gate_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.10.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.10.down_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.10.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.10.up_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.10.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.11.gate_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.11.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.11.down_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.11.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.11.up_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.11.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.12.gate_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.12.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.12.down_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.12.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.12.up_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.12.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.13.gate_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.13.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.13.down_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.13.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.13.up_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.13.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.14.gate_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.14.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.14.down_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.14.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.14.up_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.14.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.15.gate_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.15.gate_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.15.down_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.15.down_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.15.up_proj
# Signal to Noise Ratio at layer model.layers.31.moe.experts.15.up_proj = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer lm_head
# Signal to Noise Ratio at layer lm_head = 1001.5868677360704
# **************************************************

# %%
import json

def save_layers_to_json(layer_snr, filename):
    with open(filename, 'w') as file:
        serializable_data = {}
        for key, value in layer_snr.items():
            # Convert Tensors to Python numbers (for SNR) and handle other data types as needed
            snr_value = value.item() if isinstance(value, torch.Tensor) else value
            # module_str = str(value['module'])  # Assuming module representation is a string or convertible to a string
            serializable_data[key] = {'snr': snr_value}

        json.dump(serializable_data, file, indent=4)

save_layers_to_json(layer_snr, "laser_Jamba-v0.1_layer_snr_info.json")

# %%
def select_layers_for_modification(layer_snr, k):
    sorted_layers = sorted(
        layer_snr.items(), key=lambda x: x[1], reverse=False
    )
    return [layer[0] for layer in sorted_layers[:k]]

top_k_layers = select_layers_for_modification(layer_snr, 16)
print(top_k_layers, flush=True)
# Out:
# ['model.layers.18.mamba.out_proj', 'model.layers.11.mamba.out_proj', 'model.layers.17.mamba.out_proj', 'model.layers.22.mamba.out_proj', 'model.layers.19.mamba.out_proj', 'model.layers.10.mamba.out_proj', 'model.layers.16.mamba.out_proj', 'model.layers.14.mamba.out_proj', 'model.layers.21.mamba.out_proj', 'model.layers.8.mamba.out_proj', 'model.layers.24.mamba.out_proj', 'model.layers.5.mamba.out_proj', 'model.layers.3.mamba.out_proj', 'model.layers.0.mamba.out_proj', 'model.layers.7.mamba.out_proj', 'model.layers.31.mamba.out_proj']
