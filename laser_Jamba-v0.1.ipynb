# %%
model_id = "ai21labs/Jamba-v0.1"

# %%
import torch
import transformers
from transformers import AutoModelForCausalLM, BitsAndBytesConfig
import bitsandbytes as bnb
print("torch", torch.__version__)
print("transformers", transformers.__version__)

device_map = "sequential"
max_memory = {0:"20GiB", 1: "22GiB"}


quantization_config = BitsAndBytesConfig(load_in_4bit=True,
                                         llm_int8_skip_modules=["lm_head", "mamba"])

model = AutoModelForCausalLM.from_pretrained(model_id,
                                             trust_remote_code=True,
                                             torch_dtype=torch.bfloat16,
                                             attn_implementation="flash_attention_2",
                                             device_map=device_map,
                                             max_memory=max_memory,
                                             quantization_config=quantization_config)
model
# Out:
# torch 2.1.2+cu121
# transformers 4.39.2
# Loading checkpoint shards:   0%|          | 0/21 [00:00<?, ?it/s]
# JambaForCausalLM(
#   (model): JambaModel(
#     (embed_tokens): Embedding(65536, 4096, padding_idx=0)
#     (layers): ModuleList(
#       (0): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (1): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (2): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (3): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (4): JambaAttentionDecoderLayer(
#         (self_attn): JambaFlashAttention2(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (5): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (6): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (7): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (8): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (9): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (10): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (11): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (12): JambaAttentionDecoderLayer(
#         (self_attn): JambaFlashAttention2(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (13): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (14): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (15): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (16): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (17): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (18): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (19): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (20): JambaAttentionDecoderLayer(
#         (self_attn): JambaFlashAttention2(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (21): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (22): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (23): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (24): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (25): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (26): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (27): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (28): JambaAttentionDecoderLayer(
#         (self_attn): JambaFlashAttention2(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (29): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (30): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (experts): ModuleList(
#             (0): JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#       (31): JambaMambaDecoderLayer(
#         (mamba): JambaMambaMixer(
#           (conv1d): Conv1d(8192, 8192, kernel_size=(4,), stride=(1,), padding=(3,), groups=8192)
#           (act): SiLU()
#           (in_proj): Linear(in_features=4096, out_features=16384, bias=False)
#           (x_proj): Linear(in_features=8192, out_features=288, bias=False)
#           (dt_proj): Linear(in_features=256, out_features=8192, bias=True)
#           (out_proj): Linear(in_features=8192, out_features=4096, bias=False)
#           (dt_layernorm): JambaRMSNorm()
#           (B_layernorm): JambaRMSNorm()
#           (C_layernorm): JambaRMSNorm()
#         )
#         (moe): JambaSparseMoeBlock(
#           (router): Linear4bit(in_features=4096, out_features=16, bias=False)
#           (experts): ModuleList(
#             (0-15): 16 x JambaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (act_fn): SiLU()
#             )
#           )
#         )
#         (input_layernorm): JambaRMSNorm()
#         (pre_moe_layernorm): JambaRMSNorm()
#       )
#     )
#     (final_layernorm): JambaRMSNorm()
#   )
#   (lm_head): Linear(in_features=4096, out_features=65536, bias=False)
# )

# %%
import bitsandbytes.functional as F
from bitsandbytes.nn import Linear4bit
from torch.nn.modules.linear import Linear
import numpy as np
import gc

layer_snr = {}

def marchenko_pastur_threshold(sigma, n, m):
    beta = n / m if n < m else m / n
    threshold = sigma * np.sqrt((1 + np.sqrt(beta)) ** 2)
    return threshold

def estimate_sigma_with_full_iqr(S):
    q75 = torch.quantile(S, 0.75)
    q25 = torch.quantile(S, 0.25)
    iqr = q75 - q25
    sigma_estimated = (
        iqr / 1.349
    )  ## 0.6745 * sigma is the expected range between the quantiles (Q1 and Q3)
    return sigma_estimated

def calculate_snr_for_layer(module):
    if isinstance(module, Linear4bit):
        weights = F.dequantize_4bit(module.weight, module.quant_state).t().double()
    elif isinstance(module, Linear):
        weights = module.weight.double()
    else:
        assert "not Linear"
    S = torch.linalg.svdvals(weights)
    weights = weights.detach().cpu()
    S = S.detach().cpu()
    sigma_estimated = estimate_sigma_with_full_iqr(S)
    n, m = weights.shape
    mp_threshold = marchenko_pastur_threshold(sigma_estimated, n, m)
    
    signal = S[S > mp_threshold].sum()
    noise = S[S <= mp_threshold].sum()
    print("signal", signal, "noise", noise)
    snr = signal / noise if noise != 0 else float("inf")
    del S, weights
    torch.cuda.empty_cache()  # Clear PyTorch's CUDA memory cache
    gc.collect()
    return snr

def assess_layers_snr(model):
    for name, module in model.named_modules():
        if isinstance(module, Linear) or isinstance(module, Linear4bit):
            print("*" * 50, flush=True)
            print(
                f"Calculating Signal to Noise Ratio at layer {name}",
                flush=True,
            )
            snr = calculate_snr_for_layer(module)
            layer_snr[name] = snr
            print(
                f"Signal to Noise Ratio at layer {name} = {snr}",
                flush=True,
            )
            print("*" * 50, flush=True)

# %%
assess_layers_snr(model)
# Out:
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.0.mamba.in_proj
# signal tensor(4593.8420, dtype=torch.float64) noise tensor(494.2332, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.0.mamba.in_proj = 9.294888408316409
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.0.mamba.x_proj
# signal tensor(195.6183, dtype=torch.float64) noise tensor(19.8755, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.0.mamba.x_proj = 9.84220223913894
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.0.mamba.dt_proj
# signal tensor(222.5460, dtype=torch.float64) noise tensor(29.6763, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.0.mamba.dt_proj = 7.4991185326259915
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.0.mamba.out_proj
# signal tensor(2402.5999, dtype=torch.float64) noise tensor(929.7504, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.0.mamba.out_proj = 2.5841342483567633
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.0.moe.experts.0.gate_proj
# signal tensor(3658.5045, dtype=torch.float64) noise tensor(482.6119, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.0.moe.experts.0.gate_proj = 7.580635106725136
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.0.moe.experts.0.down_proj
# signal tensor(4154.4661, dtype=torch.float64) noise tensor(574.5829, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.0.moe.experts.0.down_proj = 7.230403013569163
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.0.moe.experts.0.up_proj
# signal tensor(3848.8745, dtype=torch.float64) noise tensor(676.4312, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.0.moe.experts.0.up_proj = 5.689972096561979
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.mamba.in_proj
# signal tensor(4368.1164, dtype=torch.float64) noise tensor(755.0480, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.mamba.in_proj = 5.785216782887676
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.mamba.x_proj
# signal tensor(169.6056, dtype=torch.float64) noise tensor(30.9601, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.mamba.x_proj = 5.478194471022491
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.mamba.dt_proj
# signal tensor(170.8773, dtype=torch.float64) noise tensor(52.0218, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.mamba.dt_proj = 3.284722551670451
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.mamba.out_proj
# signal tensor(2693.8136, dtype=torch.float64) noise tensor(929.1785, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.mamba.out_proj = 2.89913467713663
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.router
# signal tensor(29.7711, dtype=torch.float64) noise tensor(0., dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.router = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.0.gate_proj
# signal tensor(4232.8283, dtype=torch.float64) noise tensor(526.7225, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.0.gate_proj = 8.03616343490833
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.0.down_proj
# signal tensor(4603.2144, dtype=torch.float64) noise tensor(330.1573, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.0.down_proj = 13.942489274772266
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.0.up_proj
# signal tensor(4219.0505, dtype=torch.float64) noise tensor(523.0955, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.0.up_proj = 8.065545898027295
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.1.gate_proj
# signal tensor(4219.6068, dtype=torch.float64) noise tensor(533.8173, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.1.gate_proj = 7.904589049119508
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.1.down_proj
# signal tensor(4612.9845, dtype=torch.float64) noise tensor(320.8836, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.1.down_proj = 14.375882806983366
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.1.up_proj
# signal tensor(4203.1896, dtype=torch.float64) noise tensor(534.0689, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.1.up_proj = 7.870126767113129
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.2.gate_proj
# signal tensor(4230.7248, dtype=torch.float64) noise tensor(505.7168, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.2.gate_proj = 8.365799012589115
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.2.down_proj
# signal tensor(4499.4480, dtype=torch.float64) noise tensor(388.6870, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.2.down_proj = 11.576018866832607
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.2.up_proj
# signal tensor(4210.0066, dtype=torch.float64) noise tensor(517.0183, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.2.up_proj = 8.142858662972724
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.3.gate_proj
# signal tensor(4154.2373, dtype=torch.float64) noise tensor(562.4900, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.3.gate_proj = 7.385441618318765
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.3.down_proj
# signal tensor(4565.2862, dtype=torch.float64) noise tensor(339.2923, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.3.down_proj = 13.455318643901506
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.3.up_proj
# signal tensor(4145.5023, dtype=torch.float64) noise tensor(560.4239, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.3.up_proj = 7.397083136565173
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.4.gate_proj
# signal tensor(4194.3396, dtype=torch.float64) noise tensor(572.1085, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.4.gate_proj = 7.331370694537966
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.4.down_proj
# signal tensor(4591.5864, dtype=torch.float64) noise tensor(350.2643, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.4.down_proj = 13.10891856284267
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.4.up_proj
# signal tensor(4174.2926, dtype=torch.float64) noise tensor(565.6352, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.4.up_proj = 7.379831952854504
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.5.gate_proj
# signal tensor(4283.7384, dtype=torch.float64) noise tensor(518.0326, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.5.gate_proj = 8.26924499526459
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.5.down_proj
# signal tensor(4634.5735, dtype=torch.float64) noise tensor(332.2390, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.5.down_proj = 13.949517263877148
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.5.up_proj
# signal tensor(4257.1611, dtype=torch.float64) noise tensor(513.4682, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.5.up_proj = 8.290993275440343
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.6.gate_proj
# signal tensor(4240.0358, dtype=torch.float64) noise tensor(551.0651, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.6.gate_proj = 7.6942562997295525
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.6.down_proj
# signal tensor(4603.9757, dtype=torch.float64) noise tensor(362.2968, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.6.down_proj = 12.707747646278511
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.6.up_proj
# signal tensor(4224.6866, dtype=torch.float64) noise tensor(543.1644, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.6.up_proj = 7.777914951623674
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.7.gate_proj
# signal tensor(4219.4183, dtype=torch.float64) noise tensor(545.0796, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.7.gate_proj = 7.740921012550788
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.7.down_proj
# signal tensor(4597.0246, dtype=torch.float64) noise tensor(346.8229, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.7.down_proj = 13.25467253923946
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.7.up_proj
# signal tensor(4205.6161, dtype=torch.float64) noise tensor(540.4452, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.7.up_proj = 7.781762028713834
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.8.gate_proj
# signal tensor(4198.3168, dtype=torch.float64) noise tensor(516.3451, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.8.gate_proj = 8.130834206044728
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.8.down_proj
# signal tensor(4545.0798, dtype=torch.float64) noise tensor(363.1315, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.8.down_proj = 12.51634650269772
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.8.up_proj
# signal tensor(4187.9770, dtype=torch.float64) noise tensor(518.6503, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.8.up_proj = 8.074761043057629
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.9.gate_proj
# signal tensor(4130.0552, dtype=torch.float64) noise tensor(550.5174, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.9.gate_proj = 7.502133500578926
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.9.down_proj
# signal tensor(4522.6070, dtype=torch.float64) noise tensor(404.3125, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.9.down_proj = 11.185919043497991
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.9.up_proj
# signal tensor(4099.2548, dtype=torch.float64) noise tensor(575.5607, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.9.up_proj = 7.122193388306176
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.10.gate_proj
# signal tensor(4197.6113, dtype=torch.float64) noise tensor(531.1854, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.10.gate_proj = 7.902346952721336
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.10.down_proj
# signal tensor(4609.2759, dtype=torch.float64) noise tensor(307.1057, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.10.down_proj = 15.008761988718026
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.10.up_proj
# signal tensor(4189.1036, dtype=torch.float64) noise tensor(532.8516, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.10.up_proj = 7.861670454118347
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.11.gate_proj
# signal tensor(4159.8093, dtype=torch.float64) noise tensor(546.5529, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.11.gate_proj = 7.610991246460907
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.11.down_proj
# signal tensor(4542.4050, dtype=torch.float64) noise tensor(365.2599, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.11.down_proj = 12.436090958812995
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.11.up_proj
# signal tensor(4152.1227, dtype=torch.float64) noise tensor(555.9587, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.11.up_proj = 7.468401688905775
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.12.gate_proj
# signal tensor(3990.6449, dtype=torch.float64) noise tensor(642.0883, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.12.gate_proj = 6.215103186667363
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.12.down_proj
# signal tensor(4543.3726, dtype=torch.float64) noise tensor(347.0549, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.12.down_proj = 13.091222416873878
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.12.up_proj
# signal tensor(3986.8563, dtype=torch.float64) noise tensor(641.5862, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.12.up_proj = 6.21406150249497
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.13.gate_proj
# signal tensor(4185.9668, dtype=torch.float64) noise tensor(536.7383, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.13.gate_proj = 7.798896723973455
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.13.down_proj
# signal tensor(4591.4894, dtype=torch.float64) noise tensor(325.0128, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.13.down_proj = 14.127104261047883
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.13.up_proj
# signal tensor(4172.6228, dtype=torch.float64) noise tensor(535.8548, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.13.up_proj = 7.786853750950983
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.14.gate_proj
# signal tensor(4271.2262, dtype=torch.float64) noise tensor(505.8410, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.14.gate_proj = 8.44381144954893
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.14.down_proj
# signal tensor(4606.1388, dtype=torch.float64) noise tensor(336.6890, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.14.down_proj = 13.680694818887703
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.14.up_proj
# signal tensor(4251.3369, dtype=torch.float64) noise tensor(502.2346, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.14.up_proj = 8.464843362650093
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.15.gate_proj
# signal tensor(4244.0799, dtype=torch.float64) noise tensor(532.2033, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.15.gate_proj = 7.974546315756838
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.15.down_proj
# signal tensor(4604.1963, dtype=torch.float64) noise tensor(337.8209, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.15.down_proj = 13.62910498053289
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.1.moe.experts.15.up_proj
# signal tensor(4228.6399, dtype=torch.float64) noise tensor(523.7278, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.1.moe.experts.15.up_proj = 8.0741172020609
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.2.mamba.in_proj
# signal tensor(5019.4781, dtype=torch.float64) noise tensor(317.1384, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.2.mamba.in_proj = 15.82740683217205
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.2.mamba.x_proj
# signal tensor(238.3541, dtype=torch.float64) noise tensor(1.7841, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.2.mamba.x_proj = 133.60279803772303
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.2.mamba.dt_proj
# signal tensor(267.3644, dtype=torch.float64) noise tensor(2.1099, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.2.mamba.dt_proj = 126.72050867078481
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.2.mamba.out_proj
# signal tensor(2596.5685, dtype=torch.float64) noise tensor(932.4394, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.2.mamba.out_proj = 2.7847049397578014
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.2.moe.experts.0.gate_proj
# signal tensor(4280.5573, dtype=torch.float64) noise tensor(433.0793, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.2.moe.experts.0.gate_proj = 9.884002561744591
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.2.moe.experts.0.down_proj
# signal tensor(4697.3965, dtype=torch.float64) noise tensor(210.4440, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.2.moe.experts.0.down_proj = 22.321364021453288
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.2.moe.experts.0.up_proj
# signal tensor(4277.2735, dtype=torch.float64) noise tensor(448.5971, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.2.moe.experts.0.up_proj = 9.534777078920074
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.mamba.in_proj
# signal tensor(4925.7324, dtype=torch.float64) noise tensor(425.7251, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.mamba.in_proj = 11.570219680263856
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.mamba.x_proj
# signal tensor(234.1103, dtype=torch.float64) noise tensor(2.0880, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.mamba.x_proj = 112.12248306964787
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.mamba.dt_proj
# signal tensor(278.1153, dtype=torch.float64) noise tensor(2.4809, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.mamba.dt_proj = 112.10069290891182
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.mamba.out_proj
# signal tensor(2593.4589, dtype=torch.float64) noise tensor(1011.6774, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.mamba.out_proj = 2.5635235441462094
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.router
# signal tensor(28.7200, dtype=torch.float64) noise tensor(0., dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.router = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.0.gate_proj
# signal tensor(4486.3188, dtype=torch.float64) noise tensor(451.2627, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.0.gate_proj = 9.941700818247106
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.0.down_proj
# signal tensor(4742.7621, dtype=torch.float64) noise tensor(308.4020, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.0.down_proj = 15.378504505081548
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.0.up_proj
# signal tensor(4447.9187, dtype=torch.float64) noise tensor(463.5246, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.0.up_proj = 9.595863053233439
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.1.gate_proj
# signal tensor(4480.2729, dtype=torch.float64) noise tensor(442.6184, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.1.gate_proj = 10.122201219774633
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.1.down_proj
# signal tensor(4756.3918, dtype=torch.float64) noise tensor(275.9597, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.1.down_proj = 17.235822859948055
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.1.up_proj
# signal tensor(4472.7439, dtype=torch.float64) noise tensor(446.0425, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.1.up_proj = 10.02761752568145
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.2.gate_proj
# signal tensor(4517.7400, dtype=torch.float64) noise tensor(429.4071, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.2.gate_proj = 10.520877792972493
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.2.down_proj
# signal tensor(4672.8343, dtype=torch.float64) noise tensor(343.4760, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.2.down_proj = 13.604545323755977
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.2.up_proj
# signal tensor(4482.0905, dtype=torch.float64) noise tensor(433.0078, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.2.up_proj = 10.351062095654674
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.3.gate_proj
# signal tensor(4304.1805, dtype=torch.float64) noise tensor(413.7320, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.3.gate_proj = 10.403306095847908
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.3.down_proj
# signal tensor(4727.2846, dtype=torch.float64) noise tensor(154.5357, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.3.down_proj = 30.590241627869677
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.3.up_proj
# signal tensor(4306.6167, dtype=torch.float64) noise tensor(412.2907, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.3.up_proj = 10.445584215537824
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.4.gate_proj
# signal tensor(4497.8395, dtype=torch.float64) noise tensor(424.9981, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.4.gate_proj = 10.583200341187704
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.4.down_proj
# signal tensor(4657.3334, dtype=torch.float64) noise tensor(337.9955, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.4.down_proj = 13.779275946668896
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.4.up_proj
# signal tensor(4476.1925, dtype=torch.float64) noise tensor(429.8370, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.4.up_proj = 10.413698648427012
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.5.gate_proj
# signal tensor(4496.6387, dtype=torch.float64) noise tensor(442.7236, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.5.gate_proj = 10.156761965966222
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.5.down_proj
# signal tensor(4663.0126, dtype=torch.float64) noise tensor(347.7577, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.5.down_proj = 13.408796466375291
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.5.up_proj
# signal tensor(4470.7565, dtype=torch.float64) noise tensor(442.3874, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.5.up_proj = 10.10597677042688
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.6.gate_proj
# signal tensor(4516.7611, dtype=torch.float64) noise tensor(433.2630, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.6.gate_proj = 10.424986566718069
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.6.down_proj
# signal tensor(4697.4140, dtype=torch.float64) noise tensor(333.6772, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.6.down_proj = 14.07771781665897
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.6.up_proj
# signal tensor(4485.3149, dtype=torch.float64) noise tensor(432.3358, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.6.up_proj = 10.374608539059754
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.7.gate_proj
# signal tensor(4535.3690, dtype=torch.float64) noise tensor(431.6509, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.7.gate_proj = 10.507030740131835
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.7.down_proj
# signal tensor(4692.4071, dtype=torch.float64) noise tensor(339.6426, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.7.down_proj = 13.815718473350938
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.7.up_proj
# signal tensor(4506.6944, dtype=torch.float64) noise tensor(425.4607, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.7.up_proj = 10.592503336710887
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.8.gate_proj
# signal tensor(4537.8067, dtype=torch.float64) noise tensor(412.4788, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.8.gate_proj = 11.001309031026771
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.8.down_proj
# signal tensor(4671.9777, dtype=torch.float64) noise tensor(343.5575, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.8.down_proj = 13.598823219778504
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.8.up_proj
# signal tensor(4511.6682, dtype=torch.float64) noise tensor(411.8523, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.8.up_proj = 10.954577639493541
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.9.gate_proj
# signal tensor(4522.5963, dtype=torch.float64) noise tensor(415.3266, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.9.gate_proj = 10.88925215944801
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.9.down_proj
# signal tensor(4681.3239, dtype=torch.float64) noise tensor(336.0165, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.9.down_proj = 13.931828545140215
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.9.up_proj
# signal tensor(4490.4631, dtype=torch.float64) noise tensor(420.1535, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.9.up_proj = 10.687672717466354
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.10.gate_proj
# signal tensor(4504.6788, dtype=torch.float64) noise tensor(441.1794, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.10.gate_proj = 10.210537228877135
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.10.down_proj
# signal tensor(4677.1124, dtype=torch.float64) noise tensor(344.2764, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.10.down_proj = 13.58534322533369
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.10.up_proj
# signal tensor(4474.4889, dtype=torch.float64) noise tensor(439.6588, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.10.up_proj = 10.177184064420532
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.11.gate_proj
# signal tensor(4519.3589, dtype=torch.float64) noise tensor(435.9765, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.11.gate_proj = 10.366060935106518
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.11.down_proj
# signal tensor(4668.9736, dtype=torch.float64) noise tensor(356.3864, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.11.down_proj = 13.10087615711694
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.11.up_proj
# signal tensor(4486.2613, dtype=torch.float64) noise tensor(435.9880, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.11.up_proj = 10.28987414277658
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.12.gate_proj
# signal tensor(3977.7497, dtype=torch.float64) noise tensor(311.5310, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.12.gate_proj = 12.768392166361682
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.12.down_proj
# signal tensor(4327.7666, dtype=torch.float64) noise tensor(137.0396, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.12.down_proj = 31.580403826353685
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.12.up_proj
# signal tensor(3973.9881, dtype=torch.float64) noise tensor(310.7765, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.12.up_proj = 12.787285782386443
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.13.gate_proj
# signal tensor(4498.3568, dtype=torch.float64) noise tensor(428.6568, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.13.gate_proj = 10.49407457562386
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.13.down_proj
# signal tensor(4676.9486, dtype=torch.float64) noise tensor(335.1837, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.13.down_proj = 13.953387848985301
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.13.up_proj
# signal tensor(4467.9632, dtype=torch.float64) noise tensor(427.1066, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.13.up_proj = 10.461003682964002
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.14.gate_proj
# signal tensor(3690.7698, dtype=torch.float64) noise tensor(309.4614, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.14.gate_proj = 11.926430725038722
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.14.down_proj
# signal tensor(4027.0350, dtype=torch.float64) noise tensor(179.9344, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.14.down_proj = 22.380574046475697
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.14.up_proj
# signal tensor(3684.9942, dtype=torch.float64) noise tensor(311.3126, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.14.up_proj = 11.836958250642141
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.15.gate_proj
# signal tensor(3828.3598, dtype=torch.float64) noise tensor(324.7915, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.15.gate_proj = 11.787131116967275
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.15.down_proj
# signal tensor(4198.8027, dtype=torch.float64) noise tensor(155.0123, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.15.down_proj = 27.086907974986087
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.3.moe.experts.15.up_proj
# signal tensor(3824.6412, dtype=torch.float64) noise tensor(324.1841, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.3.moe.experts.15.up_proj = 11.797743292439439
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.4.self_attn.q_proj
# signal tensor(1159.8417, dtype=torch.float64) noise tensor(901.3038, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.4.self_attn.q_proj = 1.286848813080353
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.4.self_attn.k_proj
# signal tensor(482.4186, dtype=torch.float64) noise tensor(390.6028, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.4.self_attn.k_proj = 1.2350618115537557
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.4.self_attn.v_proj
# signal tensor(170.8489, dtype=torch.float64) noise tensor(67.5029, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.4.self_attn.v_proj = 2.5309863763223763
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.4.self_attn.o_proj
# signal tensor(633.6850, dtype=torch.float64) noise tensor(590.5715, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.4.self_attn.o_proj = 1.0730031000287599
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.4.moe.experts.0.gate_proj
# signal tensor(4393.5830, dtype=torch.float64) noise tensor(311.6532, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.4.moe.experts.0.gate_proj = 14.097666468293204
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.4.moe.experts.0.down_proj
# signal tensor(4601.9312, dtype=torch.float64) noise tensor(227.1840, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.4.moe.experts.0.down_proj = 20.256408792321682
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.4.moe.experts.0.up_proj
# signal tensor(4383.9382, dtype=torch.float64) noise tensor(379.7503, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.4.moe.experts.0.up_proj = 11.544264401478841
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.mamba.in_proj
# signal tensor(4954.3251, dtype=torch.float64) noise tensor(414.7944, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.5.mamba.in_proj = 11.944049262649637
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.mamba.x_proj
# signal tensor(248.7590, dtype=torch.float64) noise tensor(0.3440, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.5.mamba.x_proj = 723.2167229626258
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.mamba.dt_proj
# signal tensor(269.5468, dtype=torch.float64) noise tensor(0.2179, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.5.mamba.dt_proj = 1236.8903775340787
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.mamba.out_proj
# signal tensor(2580.1429, dtype=torch.float64) noise tensor(1011.0709, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.5.mamba.out_proj = 2.551891063040065
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.router
# signal tensor(24.9933, dtype=torch.float64) noise tensor(0., dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.5.moe.router = inf
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.0.gate_proj
# signal tensor(4641.4710, dtype=torch.float64) noise tensor(251.3544, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.5.moe.experts.0.gate_proj = 18.465846449474135
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.5.moe.experts.0.down_proj
# ...
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.1.up_proj
# signal tensor(5142.4623, dtype=torch.float64) noise tensor(219.3353, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.1.up_proj = 23.44566318334067
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.2.gate_proj
# signal tensor(4727.0744, dtype=torch.float64) noise tensor(351.8436, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.2.gate_proj = 13.435157615214711
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.2.down_proj
# signal tensor(4988.1625, dtype=torch.float64) noise tensor(437.7234, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.2.down_proj = 11.395696115677241
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.2.up_proj
# signal tensor(5118.6459, dtype=torch.float64) noise tensor(324.3289, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.2.up_proj = 15.782269112758934
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.3.gate_proj
# signal tensor(4759.3764, dtype=torch.float64) noise tensor(244.1071, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.3.gate_proj = 19.497083108195696
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.3.down_proj
# signal tensor(4617.1921, dtype=torch.float64) noise tensor(640.9598, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.3.down_proj = 7.203559323334303
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.3.up_proj
# signal tensor(5116.2048, dtype=torch.float64) noise tensor(215.6310, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.3.up_proj = 23.726665861556082
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.4.gate_proj
# signal tensor(4751.7291, dtype=torch.float64) noise tensor(444.3390, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.4.gate_proj = 10.693926498539504
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.4.down_proj
# signal tensor(4254.5972, dtype=torch.float64) noise tensor(1046.4168, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.4.down_proj = 4.0658725472274435
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.4.up_proj
# signal tensor(5120.6089, dtype=torch.float64) noise tensor(392.3961, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.4.up_proj = 13.049591374263324
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.5.gate_proj
# signal tensor(4793.1329, dtype=torch.float64) noise tensor(249.4753, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.5.gate_proj = 19.212858462206125
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.5.down_proj
# signal tensor(4705.0744, dtype=torch.float64) noise tensor(561.3367, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.5.down_proj = 8.381911554594158
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.5.up_proj
# signal tensor(5123.1749, dtype=torch.float64) noise tensor(201.9752, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.5.up_proj = 25.365367928288283
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.6.gate_proj
# signal tensor(4818.8129, dtype=torch.float64) noise tensor(220.1657, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.6.gate_proj = 21.887212644904217
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.6.down_proj
# signal tensor(4855.2794, dtype=torch.float64) noise tensor(413.9750, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.6.down_proj = 11.72843499790317
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.6.up_proj
# signal tensor(5188.7756, dtype=torch.float64) noise tensor(186.1905, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.6.up_proj = 27.86809543206885
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.7.gate_proj
# signal tensor(4682.4571, dtype=torch.float64) noise tensor(391.8042, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.7.gate_proj = 11.951012377748652
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.7.down_proj
# signal tensor(4964.7375, dtype=torch.float64) noise tensor(473.1113, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.7.down_proj = 10.493803519788637
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.7.up_proj
# signal tensor(5087.2268, dtype=torch.float64) noise tensor(358.3530, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.7.up_proj = 14.196132906291963
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.8.gate_proj
# signal tensor(4905.3617, dtype=torch.float64) noise tensor(248.4750, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.8.gate_proj = 19.741875603346625
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.8.down_proj
# signal tensor(4670.3374, dtype=torch.float64) noise tensor(521.1499, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.8.down_proj = 8.961601772521423
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.8.up_proj
# signal tensor(5129.0591, dtype=torch.float64) noise tensor(197.3573, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.8.up_proj = 25.98870301451219
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.9.gate_proj
# signal tensor(4955.5863, dtype=torch.float64) noise tensor(233.7736, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.9.gate_proj = 21.19823323603691
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.9.down_proj
# signal tensor(4443.1367, dtype=torch.float64) noise tensor(808.7171, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.9.down_proj = 5.494055333747656
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.9.up_proj
# signal tensor(5225.8877, dtype=torch.float64) noise tensor(193.2178, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.9.up_proj = 27.04662172358323
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.10.gate_proj
# signal tensor(5033.9191, dtype=torch.float64) noise tensor(233.1999, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.10.gate_proj = 21.586279627425387
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.10.down_proj
# signal tensor(4492.8615, dtype=torch.float64) noise tensor(733.5152, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.10.down_proj = 6.125109994128485
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.10.up_proj
# signal tensor(5180.6685, dtype=torch.float64) noise tensor(196.6136, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.10.up_proj = 26.349490513835992
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.11.gate_proj
# signal tensor(4864.4498, dtype=torch.float64) noise tensor(288.9873, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.11.gate_proj = 16.83274564624281
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.11.down_proj
# signal tensor(4903.8805, dtype=torch.float64) noise tensor(407.8086, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.11.down_proj = 12.024954775867656
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.11.up_proj
# signal tensor(5109.4284, dtype=torch.float64) noise tensor(240.2366, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.11.up_proj = 21.268318994287057
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.12.gate_proj
# signal tensor(4769.7547, dtype=torch.float64) noise tensor(251.8777, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.12.gate_proj = 18.936791676303457
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.12.down_proj
# signal tensor(4561.9718, dtype=torch.float64) noise tensor(677.6329, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.12.down_proj = 6.7322175369337955
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.12.up_proj
# signal tensor(5111.7380, dtype=torch.float64) noise tensor(211.6752, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.12.up_proj = 24.14897371510583
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.13.gate_proj
# signal tensor(4683.2406, dtype=torch.float64) noise tensor(345.0451, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.13.gate_proj = 13.572835893776626
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.13.down_proj
# signal tensor(5046.8398, dtype=torch.float64) noise tensor(350.5229, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.13.down_proj = 14.398033222551579
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.13.up_proj
# signal tensor(5051.0438, dtype=torch.float64) noise tensor(328.7893, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.13.up_proj = 15.362554830136851
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.14.gate_proj
# signal tensor(4792.1766, dtype=torch.float64) noise tensor(235.3846, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.14.gate_proj = 20.358921682509262
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.14.down_proj
# signal tensor(4660.2909, dtype=torch.float64) noise tensor(562.5021, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.14.down_proj = 8.284930965976177
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.14.up_proj
# signal tensor(5099.1507, dtype=torch.float64) noise tensor(204.9327, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.14.up_proj = 24.88206889517527
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.15.gate_proj
# signal tensor(4845.0300, dtype=torch.float64) noise tensor(200.6474, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.15.gate_proj = 24.146980272422088
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.15.down_proj
# signal tensor(4678.7339, dtype=torch.float64) noise tensor(466.6189, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.15.down_proj = 10.026884109936809
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer model.layers.31.moe.experts.15.up_proj
# signal tensor(5081.4983, dtype=torch.float64) noise tensor(148.2574, dtype=torch.float64)
# Signal to Noise Ratio at layer model.layers.31.moe.experts.15.up_proj = 34.274828188430895
# **************************************************
# **************************************************
# Calculating Signal to Noise Ratio at layer lm_head
# signal tensor(16595.8129, dtype=torch.float64) noise tensor(16.5695, dtype=torch.float64)
# Signal to Noise Ratio at layer lm_head = 1001.5868677360704
# **************************************************

# %%
import json

def save_layers_to_json(layer_snr, filename):
    with open(filename, 'w') as file:
        serializable_data = {}
        for key, value in layer_snr.items():
            # Convert Tensors to Python numbers (for SNR) and handle other data types as needed
            snr_value = value.item() if isinstance(value, torch.Tensor) else value
            # module_str = str(value['module'])  # Assuming module representation is a string or convertible to a string
            serializable_data[key] = {'snr': snr_value}

        json.dump(serializable_data, file, indent=4)

save_layers_to_json(layer_snr, "laser_Jamba-v0.1_layer_snr_info.json")

# %%
def select_layers_for_modification(layer_snr, k):
    sorted_layers = sorted(
        layer_snr.items(), key=lambda x: x[1], reverse=False
    )
    return [layer[0] for layer in sorted_layers[:k]]

top_k_layers = select_layers_for_modification(layer_snr, 16)
print(top_k_layers, flush=True)
# Out:
# ['model.layers.28.self_attn.o_proj', 'model.layers.20.self_attn.o_proj', 'model.layers.12.self_attn.o_proj', 'model.layers.4.self_attn.o_proj', 'model.layers.12.self_attn.q_proj', 'model.layers.20.self_attn.q_proj', 'model.layers.4.self_attn.k_proj', 'model.layers.4.self_attn.q_proj', 'model.layers.28.self_attn.q_proj', 'model.layers.18.mamba.out_proj', 'model.layers.28.self_attn.v_proj', 'model.layers.11.mamba.out_proj', 'model.layers.17.mamba.out_proj', 'model.layers.22.mamba.out_proj', 'model.layers.19.mamba.out_proj', 'model.layers.10.mamba.out_proj']
